# %% [markdown]
# Codigo desenvolvido pelo Prof. Dionne Monteiro

# %%
import requests
import json

#função para coletar os dados
def getSensorData(mySensor, myKey, myParams):
    #Definição da URL para captura de dados. Inclui o número do sensor.
    myUrl = 'https://api.purpleair.com/v1/sensors/' + str(mySensor)

    #Informa a API Key para a leitura dos dados.
    myHeader = {'X-API-Key':myKey}


    r = requests.get(myUrl, headers=myHeader, params=myParams)

    #print (r.content)
    return (r)


# Define a API key
api_key = '03597DDF-0334-11EF-B9F7-42010A80000D'

# Define o número do sensor de interesse
# Para obter o número do sensor, clicar no sensor desejado no mapa de sensores
# e copiar os números da URL do navegador que aparecem após "select=".
# Somente sensores públicos
sensor = 56879

# Definição dos parâmetros a serem obtidos
#params = {'fields':'temperature,pm2.5_atm'}    # Especificar os parâmetros de interesse
params = ''                                     # A string vazia retorna todos os valores

# Obtém os dados do sensor especificado e imprime o conteúdo recebido
result = getSensorData(sensor, api_key, params)
print(result.content)

# Organiza os dados JSON em um dicionário
data = json.loads(result.content)

# Imprime todos os dados da classe sensor
print("-----------------------")
print(data["sensor"])

# Imprime os dados rotulados
print("***********************")
print("Index:", data["sensor"]["sensor_index"])
print("Name:", data["sensor"]["name"])
print("Position rating:", data["sensor"]["position_rating"])
print("Latitude:", data["sensor"]["latitude"])
print("Longitude", data["sensor"]["longitude"])
print("Altitude:", data["sensor"]["altitude"])
print("Confidence:", data["sensor"]["confidence"])
print("Confidence auto:", data["sensor"]["confidence_auto"])
print("Confidence manual:", data["sensor"]["confidence_manual"])
print("Humidity:", data["sensor"]["humidity"])
print("Humidity_a:", data["sensor"]["humidity_a"])
print("Temperature:", data["sensor"]["temperature"])
print("Temperature_a:", data["sensor"]["temperature_a"])
print("Pressure:", data["sensor"]["pressure"])
print("Pressure_a:", data["sensor"]["pressure_a"])
print("Analog input:", data["sensor"]["analog_input"])
print("PM 1.0:", data["sensor"]["pm1.0"])
print("PM 1.0_a:", data["sensor"]["pm1.0_a"])
print("PM 1.0_b:", data["sensor"]["pm1.0_b"])
print("PM 2.5:", data["sensor"]["pm2.5"])
print("PM 2.5_a:", data["sensor"]["pm2.5_a"])
print("PM 2.5_b:", data["sensor"]["pm2.5_b"])
print("PM 2.5 Alt:", data["sensor"]["pm2.5_alt"])
print("PM 2.5 Alt_a:", data["sensor"]["pm2.5_alt_a"])
print("PM 2.5 Alt_b:", data["sensor"]["pm2.5_alt_b"])
print("PM 10.0:", data["sensor"]["pm10.0"])
print("PM 10.0_a:", data["sensor"]["pm10.0_a"])
print("PM 10.0_b:", data["sensor"]["pm10.0_b"])
print("Scattering coefficient:", data["sensor"]["scattering_coefficient"])
print("Scattering coefficient_a:", data["sensor"]["scattering_coefficient_a"])
print("Scattering coefficient_b:", data["sensor"]["scattering_coefficient_b"])
print("Deciviews:", data["sensor"]["deciviews"])
print("Deciviews_a:", data["sensor"]["deciviews_a"])
print("Deciviews_b:", data["sensor"]["deciviews_b"])
print("Visual range:", data["sensor"]["visual_range"])
print("Visual range_a:", data["sensor"]["visual_range_a"])
print("Visual range_b:", data["sensor"]["visual_range_b"])
print("0.3 um count:", data["sensor"]["0.3_um_count"])
print("0.3 um count_a:", data["sensor"]["0.3_um_count_a"])
print("0.3 um count_b:", data["sensor"]["0.3_um_count_b"])
print("0.5 um count:", data["sensor"]["0.5_um_count"])
print("0.5 um count_a:", data["sensor"]["0.5_um_count_a"])
print("0.5 um count_b:", data["sensor"]["0.5_um_count_b"])
print("1.0 um count:", data["sensor"]["1.0_um_count"])
print("1.0 um count_a:", data["sensor"]["1.0_um_count_a"])
print("1.0 um count_b:", data["sensor"]["1.0_um_count_b"])
print("2.5 um count:", data["sensor"]["2.5_um_count"])
print("2.5 um count_a:", data["sensor"]["2.5_um_count_a"])
print("2.5 um count_b:", data["sensor"]["2.5_um_count_b"])
print("5.0 um count:", data["sensor"]["5.0_um_count"])
print("5.0 um count_a:", data["sensor"]["5.0_um_count_a"])
print("5.0 um count_b:", data["sensor"]["5.0_um_count_b"])
print("10.0 um count:", data["sensor"]["10.0_um_count"])
print("10.0 um count_a:", data["sensor"]["10.0_um_count_a"])
print("10.0 um count_b:", data["sensor"]["10.0_um_count_b"])
print("PM 1.0 CF 1:", data["sensor"]["pm1.0_cf_1"])
print("PM 1.0 CF 1_a:", data["sensor"]["pm1.0_cf_1_a"])
print("PM 1.0 CF 1_b:", data["sensor"]["pm1.0_cf_1_b"])
print("PM 1.0 ATM:", data["sensor"]["pm1.0_atm"])
print("PM 1.0 ATM_a:", data["sensor"]["pm1.0_atm_a"])
print("PM 1.0 ATM_b:", data["sensor"]["pm1.0_atm_b"])
print("PM 2.5 ATM:", data["sensor"]["pm2.5_atm"])
print("PM 2.5 ATM_a:", data["sensor"]["pm2.5_atm_a"])
print("PM 2.5 ATM_b:", data["sensor"]["pm2.5_atm_b"])
print("PM 2.5 CF 1:", data["sensor"]["pm2.5_cf_1"])
print("PM 2.5 CF 1_a:", data["sensor"]["pm2.5_cf_1_a"])
print("PM 2.5 CF 1_b:", data["sensor"]["pm2.5_cf_1_b"])
print("PM 10.0 ATM:", data["sensor"]["pm10.0_atm"])
print("PM 10.0 ATM_a:", data["sensor"]["pm10.0_atm_a"])
print("PM 10.0 ATM_b:", data["sensor"]["pm10.0_atm_b"])
print("PM 10.0 CF 1:", data["sensor"]["pm10.0_cf_1"])
print("PM 10.0 CF 1_a:", data["sensor"]["pm10.0_cf_1_a"])
print("PM 10.0 CF 1_b:", data["sensor"]["pm10.0_cf_1_b"])
print("Primary ID_a:", data["sensor"]["primary_id_a"])
print("Primary key_a:", data["sensor"]["primary_key_a"])
print("Primary ID_b:", data["sensor"]["primary_id_b"])
print("Primary key_b:", data["sensor"]["primary_key_b"])
print("Secondary ID_a:", data["sensor"]["secondary_id_a"])
print("Secondary key_a:", data["sensor"]["secondary_key_a"])
print("Secondary ID_b:", data["sensor"]["secondary_id_b"])
print("Secondary Key_b", data["sensor"]["secondary_key_b"])
print("Stats PM 2.5:", data["sensor"]["stats"]["pm2.5"])
print("Stats PM 2.5 10 minutes:", data["sensor"]["stats"]["pm2.5_10minute"])
print("Stats PM 2.5 30 minutes:", data["sensor"]["stats"]["pm2.5_30minute"])
print("Stats PM 2.5 60 minutes:", data["sensor"]["stats"]["pm2.5_60minute"])
print("Stats PM 2.5 06 hours:", data["sensor"]["stats"]["pm2.5_6hour"])
print("Stats PM 2.5 24 hours:", data["sensor"]["stats"]["pm2.5_24hour"])
print("Stats PM 2.5 01 week:", data["sensor"]["stats"]["pm2.5_1week"])
print("Stats Timestamp:", data["sensor"]["stats"]["time_stamp"])
print("Stats_a PM 2.5:", data["sensor"]["stats_a"]["pm2.5"])
print("Stats_a PM 2.5 10 minutes:", data["sensor"]["stats_a"]["pm2.5_10minute"])
print("Stats_a PM 2.5 30 minutes:", data["sensor"]["stats_a"]["pm2.5_30minute"])
print("Stats_a PM 2.5 60 minutes:", data["sensor"]["stats_a"]["pm2.5_60minute"])
print("Stats_a PM 2.5 06 hours:", data["sensor"]["stats_a"]["pm2.5_6hour"])
print("Stats_a PM 2.5 24 hours:", data["sensor"]["stats_a"]["pm2.5_24hour"])
print("Stats_a PM 2.5 01 week:", data["sensor"]["stats_a"]["pm2.5_1week"])
print("Stats_a Timestamp:", data["sensor"]["stats_a"]["time_stamp"])
print("Stats_b PM 2.5:", data["sensor"]["stats_b"]["pm2.5"])
print("Stats_b PM 2.5 10 minutes:", data["sensor"]["stats_b"]["pm2.5_10minute"])
print("Stats_b PM 2.5 30 minutes:", data["sensor"]["stats_b"]["pm2.5_30minute"])
print("Stats_b PM 2.5 60 minutes:", data["sensor"]["stats_b"]["pm2.5_60minute"])
print("Stats_b PM 2.5 06 hours:", data["sensor"]["stats_b"]["pm2.5_6hour"])
print("Stats_b PM 2.5 24 hours:", data["sensor"]["stats_b"]["pm2.5_24hour"])
print("Stats_b PM 2.5 01 week:", data["sensor"]["stats_b"]["pm2.5_1week"])
print("Stats_b Timestamp:", data["sensor"]["stats_b"]["time_stamp"])
