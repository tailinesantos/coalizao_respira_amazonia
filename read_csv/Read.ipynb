# %% [markdown]
# Código desenvolvido por Tailine Corrêa (email: tailine.atm@gmail.com)

# %% [markdown]
# Leitura dos dados Purple air

# %%
##Library
import os
from glob import glob
from datetime import timedelta
import pandas as pd
import csv

os.chdir(r'C:\Users\taili\OneDrive\Área de Trabalho\Instituto Saude e Sustentabilidade\Monitoramento acre')

# %%
##listas por tipo geral
##lendo e juntando arquivos em pastas diferentes para cada estado

# Obter a lista de arquivos
list1=glob(r'\DadosAir_Purple\*\*(outside) * Primary Real Time*.csv')
list2=glob(r'\DadosAir_Purple\*\*(outside) * Secondary Real Time*.csv')
list3=glob(r'\DadosAir_Purple\*\*B (undefined) * Primary Real Time*.csv')
list4=glob(r'\DadosAir_Purple\*\*B (undefined) * Secondary Real Time*.csv')

# Loop para ler e processar cada arquivo
df1=pd.DataFrame([])
for file1 in list1:
    dt=pd.read_csv(file1).iloc[:,:-1] # Lê o arquivo e ignora a última coluna
    inicio = 99 + file1[99:].find('\\') + 1
    inicio=99+file1[99:].find('\\')+1
    dt['estado']=file1[99:inicio-1]
    file1=file1[inicio:]
    dt['estacao']=file1[:file1.find(')')+1]
    dt['localizacao']=file1[file1.find(')')+1:file1.find(')',file1.find(')')+1)+1]
    dt['tipo']=file1[file1.find(')',file1.find(')')+1)+1:file1.find('Time')+4]
    dt['t_inicial']=file1[-25:-15]
    dt['t_final']=file1[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df1 = pd.concat([df1, dt], ignore_index=True)
    
df2=pd.DataFrame([])
for file2 in list2:
    dt=pd.read_csv(file2).iloc[:,:-1]
    inicio=99+file2[99:].find('\\')+1
    dt['estado']=file2[99:inicio-1]
    file2=file2[inicio:]
    dt['estacao']=file2[:file2.find(')')+1]
    dt['localizacao']=file2[file2.find(')')+1:file2.find(')',file2.find(')')+1)+1]
    dt['tipo']=file2[file2.find(')',file2.find(')')+1)+1:file2.find('Time')+4]
    dt['t_inicial']=file2[-25:-15]
    dt['t_final']=file2[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df2=pd.concat([df2, dt], ignore_index=True)
    
df3=pd.DataFrame([])
for file3 in list3:
    dt=pd.read_csv(file3).iloc[:,:-1]
    inicio=99+file3[99:].find('\\')+1
    dt['estado']=file3[99:inicio-1]
    file3=file3[inicio:]
    dt['estacao']=file3[:file3.find(')')+1]
    dt['localizacao']=file3[file3.find(')')+1:file3.find(')',file3.find(')')+1)+1]
    dt['tipo']=file3[file3.find(')',file3.find(')')+1)+1:file3.find('Time')+4]
    dt['t_inicial']=file3[-25:-15]
    dt['t_final']=file3[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df3=pd.concat([df3, dt], ignore_index=True)
    
df4=pd.DataFrame([])
for file4 in list4:
    dt=pd.read_csv(file4).iloc[:,:-1]
    inicio=99+file4[99:].find('\\')+1
    dt['estado']=file4[99:inicio-1]
    file4=file4[inicio:]
    dt['estacao']=file4[:file4.find(')')+1]
    dt['localizacao']=file4[file4.find(')')+1:file4.find(')',file4.find(')')+1)+1]
    dt['tipo']=file4[file4.find(')',file4.find(')')+1)+1:file4.find('Time')+4]
    dt['t_inicial']=file4[-25:-15]
    dt['t_final']=file4[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df4=pd.concat([df4, dt], ignore_index=True)

# %%
df1

# %%
#os.chdir(r'\DadosAir_Purple')
df1.to_csv('Primary_Real_Time_outside.csv')
df2.to_csv('Secondary_Real_Time_outside.csv')
df3.to_csv('Primary_Real_Time_undefined.csv')
df4.to_csv('Secondary_Real_Time_undefined.csv')

# %% [markdown]
# Leitura e organização por estado

# %%
ap='Amapa'
am="Amazonas"
pr='Para'
rd='Rondonia'
rr='Roraima'
tc='Tocantins'
mg='Mato Grosso'

os.chdir(r'\DadosAir_Purple\Amapa')
arquivos1 = glob('*(outside)* Primary Real Time*.csv')

# %%
##listas Amapa
lista=glob(r'\DadosAir_Purple\Amapa\*.csv')
list1=glob(r'\DadosAir_Purple\Amapa\*(outside) * Primary Real Time*.csv')
list2=glob(r'\DadosAir_Purple\Amapa\*(outside) * Secondary Real Time*.csv')
list3=glob(r'\DadosAir_Purple\Amapa\*B (undefined) * Primary Real Time*.csv')
list4=glob(r'\DadosAir_Purple\Amapa\*B (undefined) * Secondary Real Time*.csv')

df1_AP=pd.DataFrame([])
for file1 in list1:
    dt=pd.read_csv(file1).iloc[:,:-1]
    inicio=99+file1[99:].find('\\')+1
    dt['estado']=file1[99:inicio-1]
    file1=file1[inicio:]
    dt['estacao']=file1[:file1.find(')')+1]
    dt['localizacao']=file1[file1.find(')')+1:file1.find(')',file1.find(')')+1)+1]
    dt['tipo']=file1[file1.find(')',file1.find(')')+1)+1:file1.find('Time')+4]
    dt['t_inicial']=file1[-25:-15]
    dt['t_final']=file1[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df1_AP=df1_AP.append(dt)
    
df2_AP=pd.DataFrame([])
for file2 in list2:
    dt=pd.read_csv(file2).iloc[:,:-1]
    
    dt['estado']=file2[99:104]
    dt['estacao']=file2[105:137]
    dt['localizacao']=file2[139:157]
    dt['tipo']=file2[159:179]
    dt['t_inicial']=file2[-25:-15]
    dt['t_final']=file2[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df2_AP=df2_AP.append(dt)
    
df3_AP=pd.DataFrame([])
for file3 in list3:
    dt=pd.read_csv(file3).iloc[:,:-1]
    dt['estado']=file3[99:104]
    dt['estacao']=file3[105:141]
    dt['localizacao']=file3[143:161]
    dt['tipo']=file3[163:181]
    dt['t_inicial']=file3[-25:-15]
    dt['t_final']=file3[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df3_AP=df3_AP.append(dt)
    
df4_AP=pd.DataFrame([])
for file4 in list4:
    dt=pd.read_csv(file4).iloc[:,:-1]
    dt['estado']=file4[99:104]
    dt['estacao']=file4[105:141]
    dt['localizacao']=file4[143:161]
    dt['tipo']=file4[159:177]
    dt['t_inicial']=file4[-25:-15]
    dt['t_final']=file4[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df4_AP=df4_AP.append(dt)

# %%
##listas Amazonas
lista=glob(r'\DadosAir_Purple\Amazonas\*.csv')
list1=glob(r'\DadosAir_Purple\Amazonas\*(outside) * Primary Real Time*.csv')
list2=glob(r'\DadosAir_Purple\Amazonas\*(outside) * Secondary Real Time*.csv')
list3=glob(r'\DadosAir_Purple\Amazonas\*B (undefined) * Primary Real Time*.csv')
list4=glob(r'\DadosAir_Purple\Amazonas\*B (undefined) * Secondary Real Time*.csv')

df1_AM=pd.DataFrame([])
for file1 in list1:
    dt=pd.read_csv(file1).iloc[:,:-1]
    dt['estado']=file1[99:107]
    dt['estacao']=file1[108:125]
    dt['localizacao']=file1[127:145]
    dt['tipo']=file1[147:165]
    dt['t_inicial']=file1[-25:-15]
    dt['t_final']=file1[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df1_AM=df1_AM.append(dt)
    
df2_AM=pd.DataFrame([])
for file2 in list2:
    dt=pd.read_csv(file2).iloc[:,:-1]
    dt['estado']=file2[99:107]
    dt['estacao']=file2[108:125]
    dt['localizacao']=file2[127:145]
    dt['tipo']=file2[147:167]
    dt['t_inicial']=file2[-25:-15]
    dt['t_final']=file2[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df2_AM=df2_AM.append(dt)
    
df3_AM=pd.DataFrame([])
for file3 in list3:
    dt=pd.read_csv(file3).iloc[:,:-1]
    dt['estado']=file3[99:107]
    dt['estacao']=file3[108:129]
    dt['localizacao']=file3[131:150]
    dt['tipo']=file3[152:169]
    dt['t_inicial']=file3[-25:-15]
    dt['t_final']=file3[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df3_AM=df3_AM.append(dt)
    
df4_AM=pd.DataFrame([])
for file4 in list4:
    dt=pd.read_csv(file4).iloc[:,:-1]
    dt['estado']=file4[99:107]
    dt['estacao']=file4[108:129]
    dt['localizacao']=file4[131:150]
    dt['tipo']=file4[152:1]
    dt['t_inicial']=file4[-25:-15]
    dt['t_final']=file4[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df4_AM=df4_AM.append(dt)

# %%
##listas Para
lista=glob(r'\DadosAir_Purple\Para\*.csv')
list1=glob(r'\DadosAir_Purple\Para\*(outside) * Primary Real Time*.csv')
list2=glob(r'\DadosAir_Purple\Para\*(outside) * Secondary Real Time*.csv')
list3=glob(r'\DadosAir_Purple\Para\*B (undefined) * Primary Real Time*.csv')
list4=glob(r'\DadosAir_Purple\Para\*B (undefined) * Secondary Real Time*.csv')

df1_PA=pd.DataFrame([])
for file1 in list1:
    dt=pd.read_csv(file1).iloc[:,:-1]
    dt['estado']=file1[99:103]
    dt['estacao']=file1[104:133]
    dt['localizacao']=file1[135:155]
    dt['tipo']=file1[157:174]
    dt['t_inicial']=file1[-25:-15]
    dt['t_final']=file1[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df1_PA=df1_PA.append(dt)
    
df2_PA=pd.DataFrame([])
for file2 in list2:
    dt=pd.read_csv(file2).iloc[:,:-1]
    dt['estado']=file2[99:103]
    dt['estacao']=file2[104:133]
    dt['localizacao']=file2[135:155]
    dt['tipo']=file2[157:176]
    dt['t_inicial']=file2[-25:-15]
    dt['t_final']=file2[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df2_PA=df2_PA.append(dt)
    
df3_PA=pd.DataFrame([])
for file3 in list3:
    dt=pd.read_csv(file3).iloc[:,:-1]
    dt['estado']=file3[99:103]
    dt['estacao']=file3[104:137]
    dt['localizacao']=file3[139:159]
    dt['tipo']=file3[161:178]
    dt['t_inicial']=file3[-25:-15]
    dt['t_final']=file3[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df3_PA=df3_PA.append(dt)
    
df4_PA=pd.DataFrame([])
for file4 in list4:
    dt=pd.read_csv(file4).iloc[:,:-1]
    dt['estado']=file4[99:103]
    dt['estacao']=file4[104:137]
    dt['localizacao']=file4[139:159]
    dt['tipo']=file4[161:180]
    dt['t_inicial']=file4[-25:-15]
    dt['t_final']=file4[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df4_PA=df4_PA.append(dt)

# %%
##listas Roraima
lista=glob(r'\DadosAir_Purple\Roraima\MPRR_BVB_01_procuradoria*.csv')
list1=glob(r'\DadosAir_Purple\Roraima\MPRR_BVB_01_procuradoria (outside) * Primary Real Time*.csv')
list2=glob(r'\DadosAir_Purple\Roraima\MPRR_BVB_01_procuradoria (outside) * Secondary Real Time*.csv')
list3=glob(r'\DadosAir_Purple\Roraima\MPRR_BVB_01_procuradoria B (undefined) * Primary Real Time*.csv')
list4=glob(r'\DadosAir_Purple\Roraima\MPRR_BVB_01_procuradoria B (undefined) * Secondary Real Time*.csv')

df1_RR=pd.DataFrame([])
for file1 in list1:
    dt=pd.read_csv(file1).iloc[:,:-1]
    dt['estado']=file1[99:106]
    dt['estacao']=file1[107:141]
    dt['localizacao']=file1[143:161]
    dt['tipo']=file1[163:180]
    dt['t_inicial']=file1[-25:-15]
    dt['t_final']=file1[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df1_RR=df1_RR.append(dt)
    
df2_RR=pd.DataFrame([])
for file2 in list2:
    dt=pd.read_csv(file2).iloc[:,:-1]
    dt['estado']=file2[99:106]
    dt['estacao']=file2[107:141]
    dt['localizacao']=file2[143:161]
    dt['tipo']=file2[163:182]
    dt['t_inicial']=file2[-25:-15]
    dt['t_final']=file2[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df2_RR=df2_RR.append(dt)
    
df3_RR=pd.DataFrame([])
for file3 in list3:
    dt=pd.read_csv(file3).iloc[:,:-1]
    dt['estado']=file3[99:106]
    dt['estacao']=file3[107:145]
    dt['localizacao']=file3[147:165]
    dt['tipo']=file3[167:184]
    dt['t_inicial']=file3[-25:-15]
    dt['t_final']=file3[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df3_RR=df3_RR.append(dt)
    
df4_RR=pd.DataFrame([])
for file4 in list4:
    dt=pd.read_csv(file4).iloc[:,:-1]
    dt['estado']=file4[99:106]
    dt['estacao']=file4[107:145]
    dt['localizacao']=file4[147:165]
    dt['tipo']=file4[167:186]
    dt['t_inicial']=file4[-25:-15]
    dt['t_final']=file4[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df4_RR=df4_RR.append(dt)

# %%
##listas Rondonia
lista=glob(r'\DadosAir_Purple\Rondonia\MPRO_PVH_01*.csv')
list1=glob(r'\DadosAir_Purple\Rondonia\MPRO_PVH_01 (outside) * Primary Real Time*.csv')
list2=glob(r'\DadosAir_Purple\Rondonia\MPRO_PVH_01 (outside) * Secondary Real Time*.csv')
list3=glob(r'\DadosAir_Purple\Rondonia\MPRO_PVH_01 B (undefined) * Primary Real Time*.csv')
list4=glob(r'\DadosAir_Purple\Rondonia\MPRO_PVH_01 B (undefined) * Secondary Real Time*.csv')

df1_RO=pd.DataFrame([])
for file1 in list1:
    dt=pd.read_csv(file1).iloc[:,:-1]
    dt['estado']=file1[99:107]
    dt['estacao']=file1[108:129]
    dt['localizacao']=file1[131:151]
    dt['tipo']=file1[153:170]
    dt['t_inicial']=file1[-25:-15]
    dt['t_final']=file1[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df1_RO=df1_RO.append(dt)
    
df2_RO=pd.DataFrame([])
for file2 in list2:
    dt=pd.read_csv(file2).iloc[:,:-1]
    dt['estado']=file2[99:107]
    dt['estacao']=file2[108:129]
    dt['localizacao']=file2[131:151]
    dt['tipo']=file2[153:172]
    dt['t_inicial']=file2[-25:-15]
    dt['t_final']=file2[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df2_RO=df2_RO.append(dt)
    
df3_RO=pd.DataFrame([])
for file3 in list3:
    dt=pd.read_csv(file3).iloc[:,:-1]
    dt['estado']=file3[99:107]
    dt['estacao']=file3[108:133]
    dt['localizacao']=file3[135:155]
    dt['tipo']=file3[157:174]
    dt['t_inicial']=file3[-25:-15]
    dt['t_final']=file3[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df3_RO=df3_RO.append(dt)
    
df4_RO=pd.DataFrame([])
for file4 in list4:
    dt=pd.read_csv(file4).iloc[:,:-1]
    dt['estado']=file4[99:107]
    dt['estacao']=file4[108:133]
    dt['localizacao']=file4[135:155]
    dt['tipo']=file4[157:176]
    dt['t_inicial']=file4[-25:-15]
    dt['t_final']=file4[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df4_RO=df4_RO.append(dt)

# %%
##listas Mato Grosso
lista=glob(r'\DadosAir_Purple\Mato Grosso\*.csv')
list1=glob(r'\DadosAir_Purple\Mato Grosso\*(outside) * Primary Real Time*.csv')
list2=glob(r'\DadosAir_Purple\Mato Grosso\*(outside) * Secondary Real Time*.csv')
list3=glob(r'\DadosAir_Purple\Mato Grosso\*B (undefined) * Primary Real Time*.csv')
list4=glob(r'\DadosAir_Purple\Mato Grosso\*B (undefined) * Secondary Real Time*.csv')

df1_MT=pd.DataFrame([])
for file1 in list1:
    dt=pd.read_csv(file1).iloc[:,:-1]
    dt['estado']=file1[99:110]
    dt['estacao']=file1[111:146]
    dt['localizacao']=file1[148:169]
    dt['tipo']=file1[171:188]
    dt['t_inicial']=file1[-25:-15]
    dt['t_final']=file1[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df1_MT=df1_MT.append(dt)
    
df2_MT=pd.DataFrame([])
for file2 in list2:
    dt=pd.read_csv(file2).iloc[:,:-1]
    dt['estado']=file2[99:110]
    dt['estacao']=file2[111:146]
    dt['localizacao']=file2[148:169]
    dt['tipo']=file2[171:190]
    dt['t_inicial']=file2[-25:-15]
    dt['t_final']=file2[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df2_MT=df2_MT.append(dt)
    
df3_MT=pd.DataFrame([])
for file3 in list3:
    dt=pd.read_csv(file3).iloc[:,:-1]
    dt['estado']=file3[99:110]
    dt['estacao']=file3[111:150]
    dt['localizacao']=file3[152:173]
    dt['tipo']=file3[175:192]
    dt['t_inicial']=file3[-25:-15]
    dt['t_final']=file3[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df3_MT=df3_MT.append(dt)
    
df4_MT=pd.DataFrame([])
for file4 in list4:
    dt=pd.read_csv(file4).iloc[:,:-1]
    dt['estado']=file4[99:110]
    dt['estacao']=file4[111:150]
    dt['localizacao']=file4[152:173]
    dt['tipo']=file4[175:194]
    dt['t_inicial']=file4[-25:-15]
    dt['t_final']=file4[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df4_MT=df4_MT.append(dt)

# %%
##listas Tocantins
lista=glob(r'\DadosAir_Purple\Tocantins\*.csv')
list1=glob(r'\DadosAir_Purple\Tocantins\*(outside) * Primary Real Time*.csv')
list2=glob(r'\DadosAir_Purple\Tocantins\*(outside) * Secondary Real Time*.csv')
list3=glob(r'\DadosAir_Purple\Tocantins\*B (undefined) * Primary Real Time*.csv')
list4=glob(r'\DadosAir_Purple\Tocantins\*B (undefined) * Secondary Real Time*.csv')

df1_TO=pd.DataFrame([])
for file1 in list1:
    dt=pd.read_csv(file1).iloc[:,:-1]
    dt['estado']=file1[99:108]
    dt['estacao']=file1[109:148]
    dt['localizacao']=file1[150:171]
    dt['tipo']=file1[173:190]
    dt['t_inicial']=file1[-25:-15]
    dt['t_final']=file1[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df1_TO=df1_TO.append(dt)
    
df2_TO=pd.DataFrame([])
for file2 in list2:
    dt=pd.read_csv(file2).iloc[:,:-1]
    dt['estado']=file2[99:108]
    dt['estacao']=file2[109:148]
    dt['localizacao']=file2[150:171]
    dt['tipo']=file2[173:192]
    dt['t_inicial']=file2[-25:-15]
    dt['t_final']=file2[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df2_TO=df2_TO.append(dt)
    
df3_TO=pd.DataFrame([])
for file3 in list3:
    dt=pd.read_csv(file3).iloc[:,:-1]
    dt['estado']=file3[99:108]
    dt['estacao']=file3[109:152]
    dt['localizacao']=file3[154:175]
    dt['tipo']=file3[177:194]
    dt['t_inicial']=file3[-25:-15]
    dt['t_final']=file3[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df3_TO=df3_TO.append(dt)
    
df4_TO=pd.DataFrame([])
for file4 in list4:
    dt=pd.read_csv(file4).iloc[:,:-1]
    dt['estado']=file4[99:108]
    dt['estacao']=file4[109:152]
    dt['localizacao']=file4[154:175]
    dt['tipo']=file4[177:196]
    dt['t_inicial']=file4[-25:-15]
    dt['t_final']=file4[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df4_TO=df4_TO.append(dt)

# %%
##listas Maranhao
lista=glob(r'\DadosAir_Purple\Maranhao\*.csv')
list1=glob(r'\DadosAir_Purple\Maranhao\*(outside) * Primary Real Time*.csv')
list2=glob(r'\DadosAir_Purple\Maranhao\*(outside) * Secondary Real Time*.csv')
list3=glob(r'\DadosAir_Purple\Maranhao\*B (undefined) * Primary Real Time*.csv')
list4=glob(r'\DadosAir_Purple\Maranhao\*B (undefined) * Secondary Real Time*.csv')

df1_MA=pd.DataFrame([])
for file1 in list1:
    dt=pd.read_csv(file1).iloc[:,:-1]
    dt['estado']=file1[99:107]
    dt['estacao']=file1[108:136]
    dt['localizacao']=file1[138:158]
    dt['tipo']=file1[160:177]
    dt['t_inicial']=file1[-25:-15]
    dt['t_final']=file1[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df1_MA=df1_MA.append(dt)
    
df2_MA=pd.DataFrame([])
for file2 in list2:
    dt=pd.read_csv(file2).iloc[:,:-1]
    dt['estado']=file2[99:107]
    dt['estacao']=file2[108:136]
    dt['localizacao']=file2[138:158]
    dt['tipo']=file2[160:179]
    dt['t_inicial']=file2[-25:-15]
    dt['t_final']=file2[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df2_MA=df2_MA.append(dt)
    
df3_MA=pd.DataFrame([])
for file3 in list3:
    dt=pd.read_csv(file3).iloc[:,:-1]
    dt['estado']=file3[99:107]
    dt['estacao']=file3[108:140]
    dt['localizacao']=file3[142:162]
    dt['tipo']=file3[164:181]
    dt['t_inicial']=file3[-25:-15]
    dt['t_final']=file3[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df3_MA=df3_MA.append(dt)
    
df4_MA=pd.DataFrame([])
for file4 in list4:
    dt=pd.read_csv(file4).iloc[:,:-1]
    dt['estado']=file4[99:107]
    dt['estacao']=file4[108:140]
    dt['localizacao']=file4[142:162]
    dt['tipo']=file4[164:183]
    dt['t_inicial']=file4[-25:-15]
    dt['t_final']=file4[-14:-4]
    dt.reset_index(drop=True,inplace=True)
    #dt.columns[0:2]=['data','id']
    df4_MA=df4_MA.append(dt)

# %%
df1=pd.DataFrame([])
df1=df1_AP.append(df1_AM)
df1=df1.append(df1_PA)
df1=df1.append(df1_RO)
df1=df1.append(df1_RR)
df1=df1.append(df1_MT)
df1=df1.append(df1_TO)
df1=df1.append(df1_MA)

df2=pd.DataFrame([])
df2=df2_AP.append(df2_AM)
df2=df2.append(df2_PA)
df2=df2.append(df2_RO)
df2=df2.append(df2_RR)
df2=df2.append(df2_MT)
df2=df2.append(df2_TO)
df2=df2.append(df2_MA)

df3=pd.DataFrame([])
df3=df3_AP.append(df3_AM)
df3=df3.append(df3_PA)
df3=df3.append(df3_RO)
df3=df3.append(df3_RR)
df3=df3.append(df3_MT)
df3=df3.append(df3_TO)
df3=df3.append(df3_MA)

df4=pd.DataFrame([])
df4=df4_AP.append(df4_AM)
df4=df4.append(df4_PA)
df4=df4.append(df4_RO)
df4=df4.append(df4_RR)
df4=df4.append(df4_MT)
df4=df4.append(df4_TO)
df4=df4.append(df4_MA)

# %%
df1_AP.columns
